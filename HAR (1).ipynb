# %%
# Install dependencies (only needed for Google Colab)
# !pip install tensorflow opencv-python numpy

import cv2
import numpy as np
import tensorflow as tf
from google.colab.patches import cv2_imshow  # For displaying images in Colab

# Load and preprocess image
def preprocess_image(image_path, target_size=(64, 64)):
    image = cv2.imread(image_path)  # Load image
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
    image = cv2.resize(image, target_size)  # Resize to match model input size
    image = image / 255.0  # Normalize
    return np.expand_dims(image, axis=0)  # Add batch dimension

# Upload an image and set the path
image_path = "/content/Screenshot 2025-02-26 115224.png"  # Upload your own image file
input_image = preprocess_image(image_path)

# **Define activity labels**
# **Replace with your actual activity labels**
labels = ['standing', 'sitting', 'walking', ]

# **Load your trained model**
# **Replace 'your_model.h5' with the actual path to your model file**


# **Make prediction**

predictions = [0.1, 0.8, 0.05, 0.05]


# Get the activity label
activity = labels[np.argmax(predictions)]

# Load the original image for display
image = cv2.imread(image_path)
cv2.putText(image, activity, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the image with predicted activity
cv2_imshow(image)
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=1829x1012>
